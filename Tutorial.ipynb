# %%
print("Hello Lomdu")

# %%
# %sql
select "Yeah Buddy ligth weight"

# %%
mydata =[(1,"aa",30 ),(2,"bb",40),(3,"cc",50)]
myschema="id INT , name String,marks INT"
df=spark.createDataFrame(mydata,schema=myschema)
display(df)

# %% [markdown]
# ### Access Data Tutorial

# %%
secret = ""
app_id = ""
ten_id = ""

# %%
spark.conf.set("fs.azure.account.auth.type.learningdb.dfs.core.windows.net", "OAuth")
spark.conf.set("fs.azure.account.oauth.provider.type.learningdb.dfs.core.windows.net", "org.apache.hadoop.fs.azurebfs.oauth2.ClientCredsTokenProvider")
spark.conf.set("fs.azure.account.oauth2.client.id.learningdb.dfs.core.windows.net", "")
spark.conf.set("fs.azure.account.oauth2.client.secret.learningdb.dfs.core.windows.net", "decret")
spark.conf.set("fs.azure.account.oauth2.client.endpoint.learningdb.dfs.core.windows.net", "https://login.microsoftonline.com/a99f41fb-911a-49c7-bc99-18b9804910b1/oauth2/token")

# %% [markdown]
# ### DB Utilities

# %% [markdown]
# ###**dbutils.fs()**

# %%
dbutils.fs.ls("abfss://source@learningdb.dfs.core.windows.net/")

# %% [markdown]
# ### dbutils.widgets()

# %%
dbutils.widgets.text("name","chirag")

# %%
var = dbutils.widgets.get("name")

# %%
var

# %% [markdown]
# ### **dbutilssecrets**

# %%
dbutils.secrets.list(scope="chiragscope")

# %%
dbutils.secrets.get(scope="chiragscope", key="ck-secret")

# %% [markdown]
# ###**Data Reading**

# %%
df= spark.read.format('csv').option("header", "true").load("abfss://source@learningdb.dfs.core.windows.net/")

# %%
df.display()

# %% [markdown]
# ### Pyspark Transformations

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df.withColumn("Item_Type",split(col("Item_Type")," ")).display()

# %%
df.withColumn("Flag",lit(var)).display()

# %%
df.withColumn("Item_Visibility",col("Item_Visibility").cast(DoubleType())).display()
